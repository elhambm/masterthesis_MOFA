# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mofax as mfx
#import os 
#os.chdir("../")

# %%
from matplotlib import rcParams
rcParams["figure.dpi"] = 200

# %%
m = mfx.mofa_model("C:/Users/beyra/Desktop/Git Repositories/s_filtering_wt&ko/s_factor_10_no_filter_wt&ko_mofa_model.hdf5")

# %%
m
# Out:
# MOFA+ model: s factor 10 no filter wt&ko mofa model
# Samples (cells): 86
# Features: 1487
# Groups: group_A (29), group_B (29), group_C (28)
# Views: Lipidomics (534), transcriptomics_KC (480), transcriptomics_hc (473)

# %%
df = m.get_weights(df=True)
df
# Out:
#                  Factor1   Factor2   Factor3   Factor4   Factor5   Factor6  \
# TAG(50:1)_TAG   0.000062 -0.040624  0.766721 -0.853934  0.003304  0.159130
# TAG(54:2)_TAG2 -0.000060  0.035375  0.610847 -0.134173  0.000826  0.008066
# TAG(54:3)_TAG2 -0.001644  0.105220  0.362795 -0.121880  0.003757  0.015718
# TAG(52:3)_TAG  -0.000940  0.180140  0.382180 -0.256140  0.000141 -0.123420
# TAG(52:2)_TAG2  0.000425  0.049762  0.020649 -0.005782 -0.000038 -0.044901
# ...                  ...       ...       ...       ...       ...       ...
# Krt8            0.002792  0.131817 -0.011001 -0.265749  0.166581  0.002361
# Mup14          -0.017633  0.001756  0.009933 -0.004110 -0.001518  0.000008
# Mup7           -0.002194 -0.027347 -0.005513 -0.164625  0.020115 -0.021005
# Krt19           0.121216  0.085571 -0.001151 -0.007101 -0.025120 -0.000001
# Msmp            0.119104  0.101455  0.051416  0.005331 -0.000023 -0.000047
#
#                  Factor7   Factor8   Factor9
# ...

# %%
#absolute sum of weights
df["sum"] = df.abs().sum(axis=1)
df
# Out:
#                  Factor1   Factor2   Factor3   Factor4   Factor5   Factor6  \
# TAG(50:1)_TAG   0.000062 -0.040624  0.766721 -0.853934  0.003304  0.159130
# TAG(54:2)_TAG2 -0.000060  0.035375  0.610847 -0.134173  0.000826  0.008066
# TAG(54:3)_TAG2 -0.001644  0.105220  0.362795 -0.121880  0.003757  0.015718
# TAG(52:3)_TAG  -0.000940  0.180140  0.382180 -0.256140  0.000141 -0.123420
# TAG(52:2)_TAG2  0.000425  0.049762  0.020649 -0.005782 -0.000038 -0.044901
# ...                  ...       ...       ...       ...       ...       ...
# Krt8            0.002792  0.131817 -0.011001 -0.265749  0.166581  0.002361
# Mup14          -0.017633  0.001756  0.009933 -0.004110 -0.001518  0.000008
# Mup7           -0.002194 -0.027347 -0.005513 -0.164625  0.020115 -0.021005
# Krt19           0.121216  0.085571 -0.001151 -0.007101 -0.025120 -0.000001
# Msmp            0.119104  0.101455  0.051416  0.005331 -0.000023 -0.000047
#
#                  Factor7   Factor8   Factor9       sum
# ...

# %%
#sort by sum
df = df.sort_values("sum", ascending=False)
df
#select top 100 features
df = df.iloc[:100]
df
# Out:
#                 Factor1   Factor2   Factor3   Factor4   Factor5   Factor6  \
# Wfdc17        -0.051657  0.126913 -0.014844 -0.349336  0.016490 -0.036681
# Rps12l1        0.061360 -0.470189  0.009413 -0.100271  3.887511 -0.004877
# Tyrobp         0.089607  0.251305  0.006644 -0.804128 -0.166682  0.000278
# Tm4sf4         0.585091  0.324693 -0.002012 -1.214551 -0.170441 -0.000004
# TAG(54:2)_TAG -2.874649 -0.138472  0.707603 -0.069987 -0.013824 -0.044498
# ...                 ...       ...       ...       ...       ...       ...
# Gm7536        -0.006461  0.828416  0.078187 -0.093178  0.325930  0.003379
# Rps12-ps3      0.125060  0.653793  0.041513 -0.868496  0.609867  0.002363
# Aldoa          0.114299  0.394684 -0.004172 -1.460780 -0.176047  0.000063
# 2900097C17Rik  0.137089  0.335531 -0.067475  1.247849 -0.000126 -0.000520
# Igkc           0.042714  0.351475  0.011870 -0.085414  1.386732 -0.005648
#
#                 Factor7   Factor8   Factor9       sum
# ...

# %%
#heatmap 
plt.figure(figsize=(10, 10))
sns.heatmap(df.drop("sum", axis=1), cmap="coolwarm", center=0, cbar_kws={"label": "Weight"})
plt.xlabel("Factor")
plt.ylabel("Feature")
plt.title("Weights")
plt.show()
